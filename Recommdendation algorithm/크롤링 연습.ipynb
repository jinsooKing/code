# %%
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# 정리
#
# 1. 동적 selenium / 정적 beautifulsoup
#
# 2.

# %%
# f'https://search.naver.com/search.naver?ssc=tab.blog.all&sm=tab_jum&query={query}'

# %%
query = '일본 여행지 추천'
url = f'https://search.naver.com/search.naver?ssc=tab.blog.all&sm=tab_jum&query={query}'

response = requests.get(url)
print(response)
# response 200 = 정상통신신호
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(response.text, 'html.parser')
results = soup.select('div.detail_box')
print(len(results))
# dsc_link
for result in results:
    title = result.select_one('div.title_area').text # 왜 얘는 .text로 가져오고
    link = result.select_one('a.title_link')['href'] # 애는 [href]로 가져오는걸까
    contents = result.select_one('div.dsc_area').text
    print(f'{title} ({link})\n {contents} \n\n')
# Out:
# 33
#  5월 일본여행지 추천 돗토리, 다카마쓰  (https://blog.naver.com/junstar1010/223853847783)
#   5월 일본여행지 추천으로 다카마쓰 정말 좋은 게 해산물들 가득한 식사를 할 수 있거든요. 인솔 팀장님이 추천해 주시는 맛집 위주로 조원들과 식도락 여행을 하니 실패할 일이 없었고 디저트에 편의점 간식까지 하루 종일 먹으며 이동했던 기억이 나네요 ㅋㅋ 오사카처럼 안 붐벼서 너무나 좋았어요. 5월 일본여행지로 다카마쓰에 가신다면 여러 섬들을 투어해 보실 수...
#
#
#  일본 여행지 추천 도쿄 VS 오사카 VS 후쿠오카 해외여행지 비교  (https://blog.naver.com/south0429/223575090496)
#   나름 여행 겁나 많이 다닌 해외여행마스터라 ㅎㅎ 여러분에게 여행지 추천을 해주기 참 좋겠더라고요~~ 유튜브 @남쪽구슬 에 최근 다녀온 해외여행 브이로그 많이 올려뒀거든요 그거 참고하시고! 도쿄, 오사카, 후쿠오카 중 고민이셨던 분들은 제 포스팅 참고하시면 좋을 것 같아요! 그럼 다음 포스팅으로 만나요 안녕~ #해외여행지추천 #일본여행지추천 #2박3일일본여행추천
#
#
#  벚꽃 따라 커플 일본 여행지 추천 BEST 5  (https://blog.naver.com/ka8564/223807065565)
#   명풍경 : 킨린 호수, 유후다케 산, 유후인 역 ✔ 볼거리 많으니 가급적 1박 2일 추천 ✔ 인근 명소 : 유후다케 산, 사기리다이 전망대, 벳푸 평소에도 유명한 일본 여행지 추천 명소 5곳은 특히 3말 4초 벚꽃이 이쁜 곳이라 일본 커플 여행하기 좋은 곳들이에요~~ #일본여행지 #일본여행지추천 #커플여행 #커플여행지 #커플여행지추천 #일본벚꽃 #일본벚꽃명소
#
#
#  일본여행지추천 오사카 근교 오카야마여행 아나크라운 플라자 오카야마 호텔  (https://blog.naver.com/minnie25/223770835551)
# ...
